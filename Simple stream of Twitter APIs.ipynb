# %% [markdown]
# Grab the modules - note also the two files you need to create, credentials.py to hold your twitter API tokens and settings.py for constants.
#
# We're using tweepy for Twitter API access http://docs.tweepy.org/en/v3.4.0/streaming_how_to.html#streaming-with-tweep

# %%
import credentials # Import api/access_token keys from credentials.py
import settings # Import related setting constants from settings.py 

import re
import tweepy
import mysql.connector
import pandas as pd
from textblob import TextBlob

# %% [markdown]
# This is Main function.
# Extracting streaming data from Twitter, pre-processing, and loading into MySQL
#
# Tweets are known as “status updates”. So the Status class in tweepy has properties describing the tweet.
# https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object.html
#
#
# We are using textblog for sentiment analyses, which is a cool library. See https://www.analyticsvidhya.com/blog/2018/02/natural-language-processing-for-beginners-using-textblob/

# %%
# Override tweepy.StreamListener to add logic to on_status
class MyStreamListener(tweepy.StreamListener):
    # Extract info from tweets
    def on_status(self, status):
        if status.retweeted:
        # Avoid retweeted info, and only original tweets will be received
            return True
        # Extract attributes from each tweet
        id_str = status.id_str
        created_at = status.created_at
        # We remove emojis (see code later on)
        text = deEmojify(status.text)    
        # We use textblog to determine sentiment
        sentiment = TextBlob(text).sentiment
        # Polarity is float which lies in the range of [-1,1]
        # where 1 means positive statement and -1 means a negative statement.
        polarity = sentiment.polarity
        # Subjective sentences generally refer to personal opinion, emotion or judgment whereas
        # objective refers to factual information. Subjectivity is also a float which lies in the range of [0,1].
        subjectivity = sentiment.subjectivity
        user_created_at = status.user.created_at
        user_location = deEmojify(status.user.location)
        user_description = deEmojify(status.user.description)
        user_followers_count =status.user.followers_count
        longitude = None
        latitude = None
        if status.coordinates:
            longitude = status.coordinates['coordinates'][0]
            latitude = status.coordinates['coordinates'][1]
            
        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        
        print(status.text)
        print("Long: {}, Lati: {}".format(longitude, latitude))
        
        # Store all data in MySQL
        if mydb.is_connected():
            mycursor = mydb.cursor()
            sql = "INSERT INTO {} (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)".format(settings.TABLE_NAME)
            val = (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, \
                user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count)
            mycursor.execute(sql, val)
            mydb.commit()
            mycursor.close()
    
    # Twitter API has rate limits, so we stop scraping data if it exceeds the threshold.
    def on_error(self, status_code):
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %% [markdown]
# Here we have the functions to clean up tweet text -- removing links, special characters, and emojis.

# %%
# Use simple regex statements to clean tweet text by removing links and special characters
def clean_tweet(self, tweet): 
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split()) 
# Get rid of emojis by stripping all non-ASCII characters
def deEmojify(text):
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %% [markdown]
# Here's the function to connect to MySQL. For some reason, this was a HUGE pain in the ass on my mac. I installed MySQL using the standard packages, but it absolutely would NOT accept the root user password that was created during installation. I have no idea WTF was going on there. I reinstalled three times with no luck.
#
# In the end I just used MAMP, which is a web server/MySQL package I use for web developement. To use it I had to add the unix socket variable below. This took an incredible amount of time to figure out.

# %%
mydb = mysql.connector.connect(
    host="localhost",
    port="3306",
    unix_socket="/Applications/MAMP/tmp/mysql/mysql.sock",
    user="chris",
    passwd="twitter",
    database="TwitterDB",
    charset = 'utf8'
)
if mydb.is_connected():
    # Check if this table exits. If not, then create a new one.
    mycursor = mydb.cursor()
    mycursor.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_name = '{0}'
        """.format(settings.TABLE_NAME))
    if mycursor.fetchone()[0] != 1:
        mycursor.execute("CREATE TABLE {} ({})".format(settings.TABLE_NAME, settings.TABLE_ATTRIBUTES))
        mydb.commit()
    mycursor.close()

# %% [markdown]
# Here we define the Twitter authentication using the credentials.py we imported at the beginning

# %%
auth  = tweepy.OAuthHandler(credentials.API_KEY, credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %% [markdown]
# And we initiate the API

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
# Close the MySQL connection as it finished
# However, this won't be reached as the stream listener won't stop automatically
# Press STOP button to finish the process.
mydb.close()
# Out:
# RT @dominiquetaegon: I just came across this video on Facebook.
#
# This man is basically crying tears of happiness because the govt’s ‘bounc…
# Long: None, Lati: None
# RT @NuneatonGriff: Ady will be going live on Facebook  @6pm to reveal the winner of the blackout. Video will be posted straight away. https…
# Long: None, Lati: None
# RT @Jordan_Sather_: Did I mention that Facebook will no longer let me run promotions on my 50,000 follower Destroying the Illusion page bec…
# Long: None, Lati: None
# RT @Realoilsheikh: You can join the Tafseer of Shaykh @DrIsaPantami live from Annur Masjid, Wuse Abuja.
#
# https://t.co/gz8SkH9P9J
# Long: None, Lati: None
# @donnaet5 @Avenger2Toxic 🙄 go figure. They stopped trying to debunk the truth and are now out right silencing it. @Facebook @Twitter
# Long: None, Lati: None
# love Facebook memes
# also this mentality is basically why I was popular in highschool https://t.co/ndTGcAqjXO
# Long: None, Lati: None
# RT @MalwareTechBlog: Did anyone really really want to be popular in school, then they look back later and see the popular kid is now having…
# Long: None, Lati: None
# RT @VikasSaraswat: Whether it is twitter, facebook or tik tok, they are only mediums. Banning either wont serve the purpose because the fil…
# Long: None, Lati: None
# Unable to #signup for the inaugural Thursdays with OMT event? Don't worry! We will #livestream the session on the O… https://t.co/WjGxfwfDB2
# Long: None, Lati: None
# RT @luvukenma: GUYS!! I FOUND THE REAL LIFE KARASUNO HIGH SCHOOL ON FACEBOOK IT'S CALLED KARUMAI HIGH SCHOOL https://t.co/wAsNy6VpL6
# Long: None, Lati: None
# Learn the new Pro Series Coax Horns
# .
# .
# .
# See you all again Tomorrow!
# Download the Zoom Meeting app and join us! Zo… https://t.co/RV0R6jK2co
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #EXO's #Suho seen in new photo released today at the #NonsanArmyTrainingCenter where he has been assigned to the secon…
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #EXO's #Suho seen in new photo released today at the #NonsanArmyTrainingCenter where he has been assigned to the secon…
# Long: None, Lati: None
# WebVR for brands are the best rules of Virtual Reality via @digitaldevnet https://t.co/5D8VBO2nlL
# Long: None, Lati: None
# @OculusSupport I was able to contact support.  Problem was due to my userId changing recently (bet other folks who… https://t.co/wlIpaJn1ZR
# Long: None, Lati: None
# Worship Harvest on Spirit TV right now 🙌
# https://t.co/c5tGg7g5IU
#
# Facebook Link👆🏽
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #EXO's #Suho seen in new photo released today at the #NonsanArmyTrainingCenter where he has been assigned to the secon…
# Long: None, Lati: None
# RT @VikasSaraswat: Whether it is twitter, facebook or tik tok, they are only mediums. Banning either wont serve the purpose because the fil…
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #GOT7’s #JB Oozes Charisma In Latest Cover Shoot For The June Issue Of #NylonKorea, And Opens Up In Cover Story About…
# Long: None, Lati: None
# OPENING CEREMONY
# FAMILY PORTRAIT #1
# (https://t.co/wzRVyg8ePZ)
#
# #처음만난친구들 #싱귤러리티 #세렌디피티 #어거스트디 #페르소나 #홉월…
# Long: None, Lati: None
# [Shop Update] Back in Stock: #KaizokuSentaiGokaiger
# - #RangerKey Set 06 #GoOnger
# - Ranger Key Set 08 #Goseiger
# - Ra… https://t.co/P61o6yWRxh
# Long: None, Lati: None
# RT @DCP_CCC_Delhi: In Case FIR registered on the complaint of @isinghapurva, all offensive posts made on Twitter and 26 posts made on Faceb…
# Long: None, Lati: None
# RT @TheRainBro: Again, thank you @143redangel. May your &amp; other private citizens' efforts not be an excuse for the government to rest on th…
# Long: None, Lati: None
# We Are #luciocosta
#
# OFFERS
# 119€ now 60€
# Only 44
#
# Made in italy 🇮🇹 only
#
# Pay with credit-card
# Free Shipping 🚛
# Orde… https://t.co/TSKGaiYmZG
# Long: 22.94219971, Lati: 40.63163973
# RT @etimes: .@lloydstevenspt promised to reveal a special treat for @tarak9999’s fans
#
# https://t.co/NXLVroofRX
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #GOT7’s #JB Oozes Charisma In Latest Cover Shoot For The June Issue Of #NylonKorea, And Opens Up In Cover Story About…
# Long: None, Lati: None
# RT @etimes: .@lloydstevenspt promised to reveal a special treat for @tarak9999’s fans
#
# https://t.co/NXLVroofRX
# Long: None, Lati: None
# Clarity Weight Loss solutions live on Facebook taking your questions about losing weight and quarantine https://t.co/G0e3qGzTp8
# Long: None, Lati: None
# RT @VioletTamaskan: There's no greater and heart warming redemption arc than the Tails from "Sonic" is NOT gay! facebook page https://t.co/…
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #EXO’s #Baekhyun will premiere his new song #Candy on May 26 and shares more adorable pics and a sweet mood teaser for…
# Long: None, Lati: None
# #SaveKoreanDogs our #SuccessStories
#
# Sharing from Cynthia White Meyer
#
# "Anna and Loki,
# LOVE STORY"
#
# #SouthKorea… https://t.co/pNtt0Npw4p
# Long: None, Lati: None
# RT @AlfredStreetBC: #ASBC Virtual Bible Study Today @ 7pm
# Join us for another session of "Can I Push It?" w/ @PastorHJW
# Come prepared to pr…
# Long: None, Lati: None
# RT @bruhziIl: Facebook wildin 🤣🤣 https://t.co/TUPxHc9kml
# Long: None, Lati: None
# RT @Gabe1Herrera: Get your gear ‼️‼️‼️
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #EXO’s #Baekhyun will premiere his new song #Candy on May 26 and shares more adorable pics and a sweet mood teaser for…
# Long: None, Lati: None
# RT @but_seekan: @DgpKarnataka @TelanganaDGP @DGP_FIRE @TheKeralaPolice @suhas06078772 @factcheckksp
# Sir, this man is provoking the publicl…
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #EXO’s #Baekhyun will premiere his new song #Candy on May 26 and shares more adorable pics and a sweet mood teaser for…
# Long: None, Lati: None
# @Joseph_Morong @gmanews Photographer talaga.
# Okay photographer and star. 🤣🤣🤣
#
# Seriously, not enough that his face h… https://t.co/3TovG1YCwA
# Long: None, Lati: None
# RT @ayua_dame: Hey guys! I saw this on Facebook. Dili najud maayo sige bilar huhu let's discipline ourselves please. This is an awareness,…
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #GOT7’s #JB Oozes Charisma In Latest Cover Shoot For The June Issue Of #NylonKorea, And Opens Up In Cover Story About…
# Long: None, Lati: None
# @BrianSpanner1 Get Facebook profile of a 16yr old school boy........watch what happens!
# Long: None, Lati: None
# RT @jfantinato: So proud of my mom...due to COVID19 she can’t teach her line dancing classes at the seniors centre...so she now does a Face…
# Long: None, Lati: None
# @BBCNews Hello, my name is Ayesha Asad. My family and I are in a life-threatening situation. We need the help of al… https://t.co/S2cWxBIjlZ
# Long: None, Lati: None
# RT @MatSouthwell: Important event for drug user organising. EuroNPUD to award 6 grants to member groups today. https://t.co/HjfWxFHr6k
# Long: None, Lati: None
# RT @robert_spalding: problem is, Facebook censors and spies too https://t.co/5UVunJZK7y
# Long: None, Lati: None
# RT @Lilmisty84: #EndTheDeathPenalty who wants to join in?
#
# #FreeTheInnocent
#  #CriminalJusticeReform https://t.co/CBQwoKoI5L
# Long: None, Lati: None
# RT @bruhziIl: Facebook wildin 🤣🤣 https://t.co/TUPxHc9kml
# Long: None, Lati: None
#
# Contact/WhatsApp us on 020554…
# Long: None, Lati: None
# I have been getting alot of reminders on my facebook memories of how excessive my drinking was leading up to the da… https://t.co/yE8lYGgfv4
# Long: None, Lati: None
# @bnceo @YESSISG16 This moron also removed Buschmann from his friend list on Facebook because Buschmann followed a B… https://t.co/iQXjahmI8e
# Long: None, Lati: None
# @prageru @Facebook Censorship is when people don't like me
# Long: None, Lati: None
# This is lovely @OldMackIsBack
# Long: None, Lati: None
# Thus the inauguration begins for the Grand Slam Championships...
#
# I'll be competing tomorrow in round 4 (8pm tomorr… https://t.co/dUvwC7h7qj
# Long: None, Lati: None
# RT @TheOliveKnife: Planning for the 2nd session on 20 Lac Cr strategy
#
# Anyone interested https://t.co/4YKKBvxKmZ
# Long: None, Lati: None
# Facebook reminded me of my short-lived career as a DJ at emo nite. Apparently playing Say Anything and One Directio… https://t.co/QyuesHkSA4
# Long: None, Lati: None
# @wobblybumkid Just delete your FB account and never look back. I did just that a year ago and I've never been happi… https://t.co/bWSY3PqMGv
# Long: None, Lati: None
# RT @bruhziIl: Facebook wildin 🤣🤣 https://t.co/TUPxHc9kml
# Long: None, Lati: None
# My dog is amazing!
# https://t.co/NLfifcdTAT
# Long: None, Lati: None
# Australia Watchdog Suggests News Boycott of Google, Facebook https://t.co/gX2snEN05v
# Long: None, Lati: None
# RT @imshin: Luxury apartments of 125, 135, 145 and 155 sqm still available in al-Raed residential building on Salah a-Din Rd. Nuseirat "ref…
# Long: None, Lati: None
# RT @TheTharnType: Twitter Like = 1 point
# Twitter Retweet = 2 points
#
# For facebook voting here's the link
# https://t.co/uxp1bhqeRc https://t.…
# Long: None, Lati: None
# RT @SayChiz: This how to handle and do it!!! Congrats ⁦@prinsesachinita⁩ You just showed everybody how to turn lemons into lemonade!!! Kudo…
# Long: None, Lati: None
# Oh man, so giddy!
# Long: None, Lati: None
# RT @EasterSealsNL: Still looking for a reason to buy a Cabin Lottery Ticket? 🌲
#
# Head over to our Facebook page to check out the interior ph…
# Long: None, Lati: None
# RT @katyperry: Tune in TONIGHT for the #AmericanIdol grand finale AND my first television performance of #Daisies! 🌼 It all starts at 8/7c…
# Long: None, Lati: None
# RT @bruhziIl: Facebook wildin 🤣🤣 https://t.co/TUPxHc9kml
# Long: None, Lati: None
# RT @prageru: BREAKING:
#
# @Facebook has reduced our page reach and implemented restrictions for "repeated sharing of false news."
#
# Facebook i…
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #GOT7’s #JB Oozes Charisma In Latest Cover Shoot For The June Issue Of #NylonKorea, And Opens Up In Cover Story About…
# Long: None, Lati: None
# RT @WORLDMUSICAWARD: #EXO’s #Baekhyun will premiere his new song #Candy on May 26 and shares more adorable pics and a sweet mood teaser for…
# Long: None, Lati: None
# RT @HarvardChanSPH: Forum event is starting now at https://t.co/sBLkW8jaLw
# Long: None, Lati: None
# RT @Stevieleedsy: 🚨 Casting call  🚨
#
# would you like the chance to be in Episode 8 ?!?!
#
# Sitting in the ☀️ thinking of scenes + characters…
# Long: None, Lati: None
# @evssofficial_ Facebook has been doing it for years. Get ready haha
# Long: None, Lati: None
# RT @bruhziIl: Facebook wildin 🤣🤣 https://t.co/TUPxHc9kml
# Long: None, Lati: None
# Our next interview for ‘Caterpillar’s in Lockdown’ is on our Facebook page. Join us as we speak to Natalie from… https://t.co/A8KSzScoZ3
# Long: None, Lati: None
# PARENTS: Dr. Javeed Sukhera (@javeedsukhera), a Child and Adolescent Psychiatrist in London, has some great tips an… https://t.co/V4h6ZIkmQ8
# Long: None, Lati: None
# Join @BrianCaskeyNC and myself for a Henderson County Happy Hour on Friday at 7 pm.
#
# FREE but RSVP for Zoom link:… https://t.co/7M64drK2N7
# Long: None, Lati: None
# RT @atomicthumbs: Photograph by Dana Hollows, posted in Facebook group "🍄 Mushroomcore 🍄" https://t.co/Go6Dn1qSOk https://t.co/IgfspI6OR7
# Long: None, Lati: None
# RT @MarjonSU: Let's all party together this Saturday at 6pm and celebrate Virtual May Ball!
#
# We have live sets from our favoruite Marjon D…
# Long: None, Lati: None
# RT @prageru: BREAKING:
#
# @Facebook has reduced our page reach and implemented restrictions for "repeated sharing of false news."
#
# Facebook i…
# Long: None, Lati: None
